# %%
# kaggle of

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\ajupe\anaconda3\lib\site-packages (1.6.6)
# Requirement already satisfied: six>=1.10 in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (1.26.16)
# Requirement already satisfied: bleach in c:\users\ajupe\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in c:\users\ajupe\anaconda3\lib\site-packages (from bleach->kaggle) (23.1)
# Requirement already satisfied: webencodings in c:\users\ajupe\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\ajupe\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajupe\anaconda3\lib\site-packages (from requests->kaggle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajupe\anaconda3\lib\site-packages (from requests->kaggle) (3.4)
# Requirement already satisfied: colorama in c:\users\ajupe\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
# !kaggle datasets download -d https://www.kaggle.com/datasets/kabure/retail-bankingdemodata?select=completedtrans.csv
# Out:
# Invalid dataset specification https://www.kaggle.com/datasets/kabure/retail-bankingdemodata?select=completedtrans.csv

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\ajupe\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajupe\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajupe\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajupe\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajupe\anaconda3\lib\site-packages (from requests) (2023.7.22)

# %%
import requests
import pandas as pd

# %%
# !kaggle datasets download -d kabure/retail-bankingdemodata
# Out:
# 401 - Unauthorized - Unauthenticated

# %%
import os

# Make sure kaggle.json is in the current directory and then set KAGGLE_CONFIG_DIR
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

# %%
# !kaggle datasets download -d kabure/retail-bankingdemodata
# Out:
# Downloading retail-bankingdemodata.zip to C:\Users\ajupe\OneDrive - New Zealand Skills & Education Group\GDDA7123C\GDDA707_Advanced Data Engineering\Assessment-2
#   0%|          | 0.00/31.8M [00:00<?, ?B/s]
#   3%|3         | 1.00M/31.8M [00:01<00:38, 831kB/s]
#   6%|6         | 2.00M/31.8M [00:01<00:18, 1.66MB/s]
#   9%|9         | 3.00M/31.8M [00:01<00:11, 2.68MB/s]
#  13%|#2        | 4.00M/31.8M [00:01<00:08, 3.33MB/s]
#  16%|#5        | 5.00M/31.8M [00:01<00:07, 3.96MB/s]
#  19%|#8        | 6.00M/31.8M [00:02<00:05, 4.61MB/s]
#  22%|##1       | 7.00M/31.8M [00:02<00:05, 4.98MB/s]
#  25%|##5       | 8.00M/31.8M [00:02<00:04, 5.41MB/s]
#  28%|##8       | 9.00M/31.8M [00:02<00:04, 5.60MB/s]
#  31%|###1      | 10.0M/31.8M [00:02<00:03, 5.80MB/s]
#  35%|###4      | 11.0M/31.8M [00:02<00:03, 5.98MB/s]
#  38%|###7      | 12.0M/31.8M [00:03<00:03, 6.07MB/s]
#  41%|####      | 13.0M/31.8M [00:03<00:03, 6.16MB/s]
#  44%|####3     | 14.0M/31.8M [00:03<00:02, 6.52MB/s]
#  47%|####7     | 15.0M/31.8M [00:03<00:02, 7.25MB/s]
#  50%|#####     | 16.0M/31.8M [00:03<00:02, 6.82MB/s]
#  57%|#####6    | 18.0M/31.8M [00:03<00:01, 7.92MB/s]
#  60%|#####9    | 19.0M/31.8M [00:04<00:01, 8.09MB/s]
#  63%|######2   | 20.0M/31.8M [00:04<00:01, 8.18MB/s]
#  66%|######5   | 21.0M/31.8M [00:04<00:01, 6.42MB/s]
#  69%|######9   | 22.0M/31.8M [00:04<00:01, 6.35MB/s]
#  75%|#######5  | 24.0M/31.8M [00:04<00:01, 7.49MB/s]
#  79%|#######8  | 25.0M/31.8M [00:04<00:00, 7.77MB/s]
#  82%|########1 | 26.0M/31.8M [00:05<00:00, 7.90MB/s]
#  85%|########4 | 27.0M/31.8M [00:05<00:00, 8.03MB/s]
#  88%|########7 | 28.0M/31.8M [00:05<00:00, 8.11MB/s]
#  91%|#########1| 29.0M/31.8M [00:05<00:00, 8.15MB/s]
#  94%|#########4| 30.0M/31.8M [00:05<00:00, 8.22MB/s]
#  97%|#########7| 31.0M/31.8M [00:05<00:00, 8.30MB/s]
# 100%|##########| 31.8M/31.8M [00:05<00:00, 8.31MB/s]
# 100%|##########| 31.8M/31.8M [00:05<00:00, 5.80MB/s]

# %%
from zipfile import ZipFile

# Adjust the file name as necessary
zip_file = "retail-bankingdemodata.zip"

with ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall()

# Optionally, remove the ZIP file after extraction
import os
os.remove(zip_file)

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('completedtrans.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
# C:\Users\ajupe\AppData\Local\Temp\ipykernel_20696\2116646077.py:4: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('completedtrans.csv')
#    column_a   trans_id account_id    type       operation  amount  balance  \
# 0         1  T00695247  A00002378  Credit  Credit in Cash   700.0    700.0
# 1         2  T00171812  A00000576  Credit  Credit in Cash   900.0    900.0
# 2         3  T00207264  A00000704  Credit  Credit in Cash  1000.0   1000.0
# 3         4  T01117247  A00003818  Credit  Credit in Cash   600.0    600.0
# 4         5  T00579373  A00001972  Credit  Credit in Cash   400.0    400.0
#
#   k_symbol bank  account  year  month  day    fulldate  fulltime  \
# 0      NaN  NaN      NaN  2013      1    1  2013-01-01  11:02:40
# 1      NaN  NaN      NaN  2013      1    1  2013-01-01  08:23:33
# 2      NaN  NaN      NaN  2013      1    1  2013-01-01  15:19:21
# 3      NaN  NaN      NaN  2013      1    1  2013-01-01  10:42:35
# 4      NaN  NaN      NaN  2013      1    2  2013-01-02  11:39:25
#
#       fulldatewithtime        date
# 0  2013-01-01T11:02:40  2013-01-01
# 1  2013-01-01T08:23:33  2013-01-01
# 2  2013-01-01T15:19:21  2013-01-01
# 3  2013-01-01T10:42:35  2013-01-01
# 4  2013-01-02T11:39:25  2013-01-02

# %%
df.shape
# Out:
# (1056320, 17)

# %%
df.isnull().sum()
# Out:
# column_a                 0
# trans_id                 0
# account_id               0
# type                     0
# operation           183114
# amount                   0
# balance                  0
# k_symbol            481881
# bank                782812
# account             760931
# year                     0
# month                    0
# day                      0
# fulldate                 0
# fulltime                 0
# fulldatewithtime         0
# date                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056320 entries, 0 to 1056319
# Data columns (total 17 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   column_a          1056320 non-null  int64
#  1   trans_id          1056320 non-null  object
#  2   account_id        1056320 non-null  object
#  3   type              1056320 non-null  object
#  4   operation         873206 non-null   object
#  5   amount            1056320 non-null  float64
#  6   balance           1056320 non-null  float64
#  7   k_symbol          574439 non-null   object
#  8   bank              273508 non-null   object
#  9   account           295389 non-null   float64
#  10  year              1056320 non-null  int64
#  11  month             1056320 non-null  int64
#  12  day               1056320 non-null  int64
#  13  fulldate          1056320 non-null  object
#  14  fulltime          1056320 non-null  object
#  15  fulldatewithtime  1056320 non-null  object
#  16  date              1056320 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 137.0+ MB

# %%
drop_columns = ['operation', 'k_symbol', 'bank', 'account']

# Assuming 'df' is your DataFrame
df = df.drop(columns=drop_columns)

# %%
df.isnull().sum()
# Out:
# column_a            0
# trans_id            0
# account_id          0
# type                0
# amount              0
# balance             0
# year                0
# month               0
# day                 0
# fulldate            0
# fulltime            0
# fulldatewithtime    0
# date                0
# dtype: int64

# %%
df.drop(columns=['column_a'], inplace=True)

# %%
#checking duplicate values 
duplicates = df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [trans_id, account_id, type, amount, balance, year, month, day, fulldate, fulltime, fulldatewithtime, date]
# Index: []

# %%
df.head(2)
# Out:
#     trans_id account_id    type  amount  balance  year  month  day  \
# 0  T00695247  A00002378  Credit   700.0    700.0  2013      1    1
# 1  T00171812  A00000576  Credit   900.0    900.0  2013      1    1
#
#      fulldate  fulltime     fulldatewithtime        date
# 0  2013-01-01  11:02:40  2013-01-01T11:02:40  2013-01-01
# 1  2013-01-01  08:23:33  2013-01-01T08:23:33  2013-01-01

# %%
#uploading data to MongoDB

# %%
#import libraries
import pymongo
import pandas as pd
import json

# %%
#connect to mongodb
client = pymongo.MongoClient("mongodb+srv://ajupeter:student2023@mongodbcluster.s7xdaor.mongodb.net/?retryWrites=true&w=majority&appName=MongoDBCluster")

# %%
#create a new collection
collection_name = "GDDA707A2"

#convert dataframe to a list of dictionaries
data_list = df.to_dict(orient='records')

# %%
#print result
data_list
# Out:
# [{'trans_id': 'T00695247',
#   'account_id': 'A00002378',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'fulldate': '2013-01-01',
#   'fulltime': '11:02:40',
#   'fulldatewithtime': '2013-01-01T11:02:40',
#   'date': '2013-01-01'},
#  {'trans_id': 'T00171812',
#   'account_id': 'A00000576',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'fulldate': '2013-01-01',
#   'fulltime': '08:23:33',
#   'fulldatewithtime': '2013-01-01T08:23:33',
#   'date': '2013-01-01'},
#  {'trans_id': 'T00207264',
#   'account_id': 'A00000704',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'fulldate': '2013-01-01',
#   'fulltime': '15:19:21',
#   'fulldatewithtime': '2013-01-01T15:19:21',
#   'date': '2013-01-01'},
#  {'trans_id': 'T01117247',
#   'account_id': 'A00003818',
#   'type': 'Credit',
#   'amount': 600.0,
#   'balance': 600.0,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'fulldate': '2013-01-01',
#   'fulltime': '10:42:35',
#   'fulldatewithtime': '2013-01-01T10:42:35',
#   'date': '2013-01-01'},
#  {'trans_id': 'T00579373',
#   'account_id': 'A00001972',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'fulldate': '2013-01-02',
#   'fulltime': '11:39:25',
#   'fulldatewithtime': '2013-01-02T11:39:25',
#   'date': '2013-01-02'},
#  {'trans_id': 'T00771035',
#   'account_id': 'A00002632',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'fulldate': '2013-01-02',
#   'fulltime': '15:15:12',
#   'fulldatewithtime': '2013-01-02T15:15:12',
#   'date': '2013-01-02'},
#  {'trans_id': 'T00452728',
#   'account_id': 'A00001539',
#   'type': 'Credit',
#   'amount': 600.0,
#   'balance': 600.0,
#   'year': 2013,
#   'month': 1,
#   'day': 3,
#   'fulldate': '2013-01-03',
#   'fulltime': '09:34:29',
#   'fulldatewithtime': '2013-01-03T09:34:29',
#   'date': '2013-01-03'},
#  {'trans_id': 'T00725751',
#   'account_id': 'A00002484',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 3,
#   'fulldate': '2013-01-03',
#   'fulltime': '09:36:35',
#   'fulldatewithtime': '2013-01-03T09:36:35',
#   'date': '2013-01-03'},
#  {'trans_id': 'T00497211',
#   'account_id': 'A00001695',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 3,
#   'fulldate': '2013-01-03',
#   'fulltime': '15:22:23',
#   'fulldatewithtime': '2013-01-03T15:22:23',
#   'date': '2013-01-03'},
#  {'trans_id': 'T00232960',
#   'account_id': 'A00000793',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 3,
#   'fulldate': '2013-01-03',
#   'fulltime': '15:08:16',
#   'fulldatewithtime': '2013-01-03T15:08:16',
#   'date': '2013-01-03'},
#  {'trans_id': 'T00505240',
#   'account_id': 'A00001726',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 3,
#   'fulldate': '2013-01-03',
#   'fulltime': '13:54:49',
#   'fulldatewithtime': '2013-01-03T13:54:49',
#   'date': '2013-01-03'},
#  {'trans_id': 'T00144541',
#   'account_id': 'A00000485',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 4,
#   'fulldate': '2013-01-04',
#   'fulltime': '16:40:53',
#   'fulldatewithtime': '2013-01-04T16:40:53',
#   'date': '2013-01-04'},
#  {'trans_id': 'T00637741',
#   'account_id': 'A00002177',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 4,
#   'fulldate': '2013-01-04',
#   'fulltime': '10:30:59',
#   'fulldatewithtime': '2013-01-04T10:30:59',
#   'date': '2013-01-04'},
#  {'trans_id': 'T00689827',
#   'account_id': 'A00002357',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 4,
#   'fulldate': '2013-01-04',
#   'fulltime': '16:29:16',
#   'fulldatewithtime': '2013-01-04T16:29:16',
#   'date': '2013-01-04'},
#  {'trans_id': 'T00846006',
#   'account_id': 'A00002881',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 4,
#   'fulldate': '2013-01-04',
#   'fulltime': '09:29:01',
#   'fulldatewithtime': '2013-01-04T09:29:01',
#   'date': '2013-01-04'},
#  {'trans_id': 'T00637742',
#   'account_id': 'A00002177',
#   'type': 'Credit',
#   'amount': 5123.0,
#   'balance': 5923.0,
#   'year': 2013,
#   'month': 1,
#   'day': 5,
#   'fulldate': '2013-01-05',
#   'fulltime': '16:44:42',
#   'fulldatewithtime': '2013-01-05T16:44:42',
#   'date': '2013-01-05'},
#  {'trans_id': 'T02908688',
#   'account_id': 'A00009635',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 5,
#   'fulldate': '2013-01-05',
#   'fulltime': '13:32:11',
#   'fulldatewithtime': '2013-01-05T13:32:11',
#   'date': '2013-01-05'},
#  {'trans_id': 'T00232961',
#   'account_id': 'A00000793',
#   'type': 'Credit',
#   'amount': 3401.0,
#   'balance': 4201.0,
#   'year': 2013,
#   'month': 1,
#   'day': 5,
#   'fulldate': '2013-01-05',
#   'fulltime': '11:56:11',
#   'fulldatewithtime': '2013-01-05T11:56:11',
#   'date': '2013-01-05'},
#  {'trans_id': 'T00192096',
#   'account_id': 'A00000652',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 5,
#   'fulldate': '2013-01-05',
#   'fulltime': '09:28:49',
#   'fulldatewithtime': '2013-01-05T09:28:49',
#   'date': '2013-01-05'},
#  {'trans_id': 'T00542215',
#   'account_id': 'A00001844',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 6,
#   'fulldate': '2013-01-06',
#   'fulltime': '14:38:54',
#   'fulldatewithtime': '2013-01-06T14:38:54',
#   'date': '2013-01-06'},
#  {'trans_id': 'T00565654',
#   'account_id': 'A00001926',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 6,
#   'fulldate': '2013-01-06',
#   'fulltime': '11:41:28',
#   'fulldatewithtime': '2013-01-06T11:41:28',
#   'date': '2013-01-06'},
#  {'trans_id': 'T00542216',
#   'account_id': 'A00001844',
#   'type': 'Credit',
#   'amount': 3242.0,
#   'balance': 3742.0,
#   'year': 2013,
#   'month': 1,
#   'day': 7,
#   'fulldate': '2013-01-07',
#   'fulltime': '10:11:45',
#   'fulldatewithtime': '2013-01-07T10:11:45',
#   'date': '2013-01-07'},
#  {'trans_id': 'T01027725',
#   'account_id': 'A00003510',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 7,
#   'fulldate': '2013-01-07',
#   'fulltime': '08:59:48',
#   'fulldatewithtime': '2013-01-07T08:59:48',
#   'date': '2013-01-07'},
#  {'trans_id': 'T00374589',
#   'account_id': 'A00001276',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 7,
#   'fulldate': '2013-01-07',
#   'fulltime': '13:53:48',
#   'fulldatewithtime': '2013-01-07T13:53:48',
#   'date': '2013-01-07'},
#  {'trans_id': 'T00579374',
#   'account_id': 'A00001972',
#   'type': 'Credit',
#   'amount': 5298.0,
#   'balance': 5698.0,
#   'year': 2013,
#   'month': 1,
#   'day': 7,
#   'fulldate': '2013-01-07',
#   'fulltime': '08:09:01',
#   'fulldatewithtime': '2013-01-07T08:09:01',
#   'date': '2013-01-07'},
#  {'trans_id': 'T00699220',
#   'account_id': 'A00002393',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 7,
#   'fulldate': '2013-01-07',
#   'fulltime': '09:44:19',
#   'fulldatewithtime': '2013-01-07T09:44:19',
#   'date': '2013-01-07'},
#  {'trans_id': 'T00129502',
#   'account_id': 'A00000435',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '11:33:46',
#   'fulldatewithtime': '2013-01-08T11:33:46',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00374590',
#   'account_id': 'A00001276',
#   'type': 'Credit',
#   'amount': 6774.0,
#   'balance': 7174.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '10:41:24',
#   'fulldatewithtime': '2013-01-08T10:41:24',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00057433',
#   'account_id': 'A00000192',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '11:27:40',
#   'fulldatewithtime': '2013-01-08T11:27:40',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00497212',
#   'account_id': 'A00001695',
#   'type': 'Credit',
#   'amount': 11832.0,
#   'balance': 12032.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '11:42:14',
#   'fulldatewithtime': '2013-01-08T11:42:14',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00621760',
#   'account_id': 'A00002122',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '13:23:47',
#   'fulldatewithtime': '2013-01-08T13:23:47',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00480214',
#   'account_id': 'A00001637',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '14:01:07',
#   'fulldatewithtime': '2013-01-08T14:01:07',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00612392',
#   'account_id': 'A00002087',
#   'type': 'Credit',
#   'amount': 600.0,
#   'balance': 600.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '13:21:14',
#   'fulldatewithtime': '2013-01-08T13:21:14',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00224342',
#   'account_id': 'A00000764',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '10:25:46',
#   'fulldatewithtime': '2013-01-08T10:25:46',
#   'date': '2013-01-08'},
#  {'trans_id': 'T01049881',
#   'account_id': 'A00003592',
#   'type': 'Credit',
#   'amount': 600.0,
#   'balance': 600.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '13:49:31',
#   'fulldatewithtime': '2013-01-08T13:49:31',
#   'date': '2013-01-08'},
#  {'trans_id': 'T01132662',
#   'account_id': 'A00003871',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '14:07:56',
#   'fulldatewithtime': '2013-01-08T14:07:56',
#   'date': '2013-01-08'},
#  {'trans_id': 'T01021120',
#   'account_id': 'A00003487',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 8,
#   'fulldate': '2013-01-08',
#   'fulltime': '08:08:38',
#   'fulldatewithtime': '2013-01-08T08:08:38',
#   'date': '2013-01-08'},
#  {'trans_id': 'T00439035',
#   'account_id': 'A00001493',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 9,
#   'fulldate': '2013-01-09',
#   'fulltime': '09:39:13',
#   'fulldatewithtime': '2013-01-09T09:39:13',
#   'date': '2013-01-09'},
#  {'trans_id': 'T00110534',
#   'account_id': 'A00000374',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 9,
#   'fulldate': '2013-01-09',
#   'fulltime': '09:09:09',
#   'fulldatewithtime': '2013-01-09T09:09:09',
#   'date': '2013-01-09'},
#  {'trans_id': 'T00771036',
#   'account_id': 'A00002632',
#   'type': 'Credit',
#   'amount': 14264.0,
#   'balance': 15364.0,
#   'year': 2013,
#   'month': 1,
#   'day': 9,
#   'fulldate': '2013-01-09',
#   'fulltime': '09:27:45',
#   'fulldatewithtime': '2013-01-09T09:27:45',
#   'date': '2013-01-09'},
#  {'trans_id': 'T00506450',
#   'account_id': 'A00001730',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 9,
#   'fulldate': '2013-01-09',
#   'fulltime': '11:42:16',
#   'fulldatewithtime': '2013-01-09T11:42:16',
#   'date': '2013-01-09'},
#  {'trans_id': 'T00192097',
#   'account_id': 'A00000652',
#   'type': 'Credit',
#   'amount': 13851.0,
#   'balance': 14551.0,
#   'year': 2013,
#   'month': 1,
#   'day': 9,
#   'fulldate': '2013-01-09',
#   'fulltime': '16:46:01',
#   'fulldatewithtime': '2013-01-09T16:46:01',
#   'date': '2013-01-09'},
#  {'trans_id': 'T01117248',
#   'account_id': 'A00003818',
#   'type': 'Credit',
#   'amount': 17366.0,
#   'balance': 17966.0,
#   'year': 2013,
#   'month': 1,
#   'day': 9,
#   'fulldate': '2013-01-09',
#   'fulltime': '08:09:03',
#   'fulldatewithtime': '2013-01-09T08:09:03',
#   'date': '2013-01-09'},
#  {'trans_id': 'T00695720',
#   'account_id': 'A00002379',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 10,
#   'fulldate': '2013-01-10',
#   'fulltime': '15:55:39',
#   'fulldatewithtime': '2013-01-10T15:55:39',
#   'date': '2013-01-10'},
#  {'trans_id': 'T00857973',
#   'account_id': 'A00002925',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 10,
#   'fulldate': '2013-01-10',
#   'fulltime': '12:19:11',
#   'fulldatewithtime': '2013-01-10T12:19:11',
#   'date': '2013-01-10'},
#  {'trans_id': 'T00477638',
#   'account_id': 'A00001628',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 10,
#   'fulldate': '2013-01-10',
#   'fulltime': '08:10:26',
#   'fulldatewithtime': '2013-01-10T08:10:26',
#   'date': '2013-01-10'},
#  {'trans_id': 'T01049882',
#   'account_id': 'A00003592',
#   'type': 'Credit',
#   'amount': 6007.0,
#   'balance': 6607.0,
#   'year': 2013,
#   'month': 1,
#   'day': 10,
#   'fulldate': '2013-01-10',
#   'fulltime': '09:02:13',
#   'fulldatewithtime': '2013-01-10T09:02:13',
#   'date': '2013-01-10'},
#  {'trans_id': 'T00252644',
#   'account_id': 'A00000866',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 10,
#   'fulldate': '2013-01-10',
#   'fulltime': '10:45:25',
#   'fulldatewithtime': '2013-01-10T10:45:25',
#   'date': '2013-01-10'},
#  {'trans_id': 'T00393505',
#   'account_id': 'A00001338',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 11,
#   'fulldate': '2013-01-11',
#   'fulltime': '08:34:56',
#   'fulldatewithtime': '2013-01-11T08:34:56',
#   'date': '2013-01-11'},
#  {'trans_id': 'T00171813',
#   'account_id': 'A00000576',
#   'type': 'Credit',
#   'amount': 6207.0,
#   'balance': 7107.0,
#   'year': 2013,
#   'month': 1,
#   'day': 11,
#   'fulldate': '2013-01-11',
#   'fulltime': '16:36:38',
#   'fulldatewithtime': '2013-01-11T16:36:38',
#   'date': '2013-01-11'},
#  {'trans_id': 'T00581699',
#   'account_id': 'A00001979',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 11,
#   'fulldate': '2013-01-11',
#   'fulltime': '12:20:47',
#   'fulldatewithtime': '2013-01-11T12:20:47',
#   'date': '2013-01-11'},
#  {'trans_id': 'T00252645',
#   'account_id': 'A00000866',
#   'type': 'Credit',
#   'amount': 12644.0,
#   'balance': 13144.0,
#   'year': 2013,
#   'month': 1,
#   'day': 11,
#   'fulldate': '2013-01-11',
#   'fulltime': '15:04:16',
#   'fulldatewithtime': '2013-01-11T15:04:16',
#   'date': '2013-01-11'},
#  {'trans_id': 'T00101386',
#   'account_id': 'A00000346',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 11,
#   'fulldate': '2013-01-11',
#   'fulltime': '11:25:35',
#   'fulldatewithtime': '2013-01-11T11:25:35',
#   'date': '2013-01-11'},
#  {'trans_id': 'T00689828',
#   'account_id': 'A00002357',
#   'type': 'Credit',
#   'amount': 6434.0,
#   'balance': 7234.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '10:30:16',
#   'fulldatewithtime': '2013-01-12T10:30:16',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00725752',
#   'account_id': 'A00002484',
#   'type': 'Credit',
#   'amount': 14779.0,
#   'balance': 15879.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '16:47:37',
#   'fulldatewithtime': '2013-01-12T16:47:37',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00565655',
#   'account_id': 'A00001926',
#   'type': 'Credit',
#   'amount': 4507.0,
#   'balance': 5207.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '13:52:16',
#   'fulldatewithtime': '2013-01-12T13:52:16',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00857974',
#   'account_id': 'A00002925',
#   'type': 'Credit',
#   'amount': 6446.0,
#   'balance': 7446.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '12:34:59',
#   'fulldatewithtime': '2013-01-12T12:34:59',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00560898',
#   'account_id': 'A00001909',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '14:13:45',
#   'fulldatewithtime': '2013-01-12T14:13:45',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00207265',
#   'account_id': 'A00000704',
#   'type': 'Credit',
#   'amount': 17477.0,
#   'balance': 18477.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '11:04:49',
#   'fulldatewithtime': '2013-01-12T11:04:49',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00477639',
#   'account_id': 'A00001628',
#   'type': 'Credit',
#   'amount': 4276.0,
#   'balance': 4976.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '11:14:10',
#   'fulldatewithtime': '2013-01-12T11:14:10',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00615542',
#   'account_id': 'A00002099',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 12,
#   'fulldate': '2013-01-12',
#   'fulltime': '13:13:38',
#   'fulldatewithtime': '2013-01-12T13:13:38',
#   'date': '2013-01-12'},
#  {'trans_id': 'T00439036',
#   'account_id': 'A00001493',
#   'type': 'Credit',
#   'amount': 5009.0,
#   'balance': 5209.0,
#   'year': 2013,
#   'month': 1,
#   'day': 13,
#   'fulldate': '2013-01-13',
#   'fulltime': '14:38:37',
#   'fulldatewithtime': '2013-01-13T14:38:37',
#   'date': '2013-01-13'},
#  {'trans_id': 'T01100759',
#   'account_id': 'A00003760',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 13,
#   'fulldate': '2013-01-13',
#   'fulltime': '15:18:01',
#   'fulldatewithtime': '2013-01-13T15:18:01',
#   'date': '2013-01-13'},
#  {'trans_id': 'T00480215',
#   'account_id': 'A00001637',
#   'type': 'Credit',
#   'amount': 5718.0,
#   'balance': 6218.0,
#   'year': 2013,
#   'month': 1,
#   'day': 13,
#   'fulldate': '2013-01-13',
#   'fulltime': '14:23:02',
#   'fulldatewithtime': '2013-01-13T14:23:02',
#   'date': '2013-01-13'},
#  {'trans_id': 'T01548749',
#   'account_id': 'A00005270',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 13,
#   'fulldate': '2013-01-13',
#   'fulltime': '13:11:54',
#   'fulldatewithtime': '2013-01-13T13:11:54',
#   'date': '2013-01-13'},
#  {'trans_id': 'T00505241',
#   'account_id': 'A00001726',
#   'type': 'Credit',
#   'amount': 13967.0,
#   'balance': 14967.0,
#   'year': 2013,
#   'month': 1,
#   'day': 13,
#   'fulldate': '2013-01-13',
#   'fulltime': '12:29:39',
#   'fulldatewithtime': '2013-01-13T12:29:39',
#   'date': '2013-01-13'},
#  {'trans_id': 'T00846007',
#   'account_id': 'A00002881',
#   'type': 'Credit',
#   'amount': 6959.0,
#   'balance': 7659.0,
#   'year': 2013,
#   'month': 1,
#   'day': 13,
#   'fulldate': '2013-01-13',
#   'fulltime': '14:39:11',
#   'fulldatewithtime': '2013-01-13T14:39:11',
#   'date': '2013-01-13'},
#  {'trans_id': 'T01021121',
#   'account_id': 'A00003487',
#   'type': 'Credit',
#   'amount': 15914.0,
#   'balance': 16714.0,
#   'year': 2013,
#   'month': 1,
#   'day': 13,
#   'fulldate': '2013-01-13',
#   'fulltime': '13:39:09',
#   'fulldatewithtime': '2013-01-13T13:39:09',
#   'date': '2013-01-13'},
#  {'trans_id': 'T02908689',
#   'account_id': 'A00009635',
#   'type': 'Credit',
#   'amount': 4470.0,
#   'balance': 4870.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '14:50:59',
#   'fulldatewithtime': '2013-01-14T14:50:59',
#   'date': '2013-01-14'},
#  {'trans_id': 'T00858384',
#   'account_id': 'A00002926',
#   'type': 'Credit',
#   'amount': 600.0,
#   'balance': 600.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '10:12:59',
#   'fulldatewithtime': '2013-01-14T10:12:59',
#   'date': '2013-01-14'},
#  {'trans_id': 'T00498389',
#   'account_id': 'A00001699',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '14:55:00',
#   'fulldatewithtime': '2013-01-14T14:55:00',
#   'date': '2013-01-14'},
#  {'trans_id': 'T00699221',
#   'account_id': 'A00002393',
#   'type': 'Credit',
#   'amount': 10737.0,
#   'balance': 11637.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '14:59:01',
#   'fulldatewithtime': '2013-01-14T14:59:01',
#   'date': '2013-01-14'},
#  {'trans_id': 'T01142758',
#   'account_id': 'A00003909',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '14:49:02',
#   'fulldatewithtime': '2013-01-14T14:49:02',
#   'date': '2013-01-14'},
#  {'trans_id': 'T01548750',
#   'account_id': 'A00005270',
#   'type': 'Credit',
#   'amount': 44749.0,
#   'balance': 45549.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '09:52:52',
#   'fulldatewithtime': '2013-01-14T09:52:52',
#   'date': '2013-01-14'},
#  {'trans_id': 'T00506836',
#   'account_id': 'A00001731',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '16:20:17',
#   'fulldatewithtime': '2013-01-14T16:20:17',
#   'date': '2013-01-14'},
#  {'trans_id': 'T03393738',
#   'account_id': 'A00011265',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 14,
#   'fulldate': '2013-01-14',
#   'fulltime': '11:58:13',
#   'fulldatewithtime': '2013-01-14T11:58:13',
#   'date': '2013-01-14'},
#  {'trans_id': 'T00621775',
#   'account_id': 'A00002122',
#   'type': 'Credit',
#   'amount': 46552.0,
#   'balance': 46852.0,
#   'year': 2013,
#   'month': 1,
#   'day': 15,
#   'fulldate': '2013-01-15',
#   'fulltime': '10:12:11',
#   'fulldatewithtime': '2013-01-15T10:12:11',
#   'date': '2013-01-15'},
#  {'trans_id': 'T00737258',
#   'account_id': 'A00002519',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 15,
#   'fulldate': '2013-01-15',
#   'fulltime': '15:25:00',
#   'fulldatewithtime': '2013-01-15T15:25:00',
#   'date': '2013-01-15'},
#  {'trans_id': 'T00144549',
#   'account_id': 'A00000485',
#   'type': 'Credit',
#   'amount': 13156.0,
#   'balance': 13456.0,
#   'year': 2013,
#   'month': 1,
#   'day': 16,
#   'fulldate': '2013-01-16',
#   'fulltime': '14:32:23',
#   'fulldatewithtime': '2013-01-16T14:32:23',
#   'date': '2013-01-16'},
#  {'trans_id': 'T00435762',
#   'account_id': 'A00001481',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 17,
#   'fulldate': '2013-01-17',
#   'fulltime': '14:42:51',
#   'fulldatewithtime': '2013-01-17T14:42:51',
#   'date': '2013-01-17'},
#  {'trans_id': 'T01027726',
#   'account_id': 'A00003510',
#   'type': 'Credit',
#   'amount': 23323.0,
#   'balance': 23823.0,
#   'year': 2013,
#   'month': 1,
#   'day': 17,
#   'fulldate': '2013-01-17',
#   'fulltime': '08:48:50',
#   'fulldatewithtime': '2013-01-17T08:48:50',
#   'date': '2013-01-17'},
#  {'trans_id': 'T03122924',
#   'account_id': 'A00010364',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 17,
#   'fulldate': '2013-01-17',
#   'fulltime': '12:57:05',
#   'fulldatewithtime': '2013-01-17T12:57:05',
#   'date': '2013-01-17'},
#  {'trans_id': 'T01176385',
#   'account_id': 'A00004034',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 18,
#   'fulldate': '2013-01-18',
#   'fulltime': '15:59:05',
#   'fulldatewithtime': '2013-01-18T15:59:05',
#   'date': '2013-01-18'},
#  {'trans_id': 'T00119435',
#   'account_id': 'A00000401',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 18,
#   'fulldate': '2013-01-18',
#   'fulltime': '11:37:05',
#   'fulldatewithtime': '2013-01-18T11:37:05',
#   'date': '2013-01-18'},
#  {'trans_id': 'T01100767',
#   'account_id': 'A00003760',
#   'type': 'Credit',
#   'amount': 10792.0,
#   'balance': 11792.0,
#   'year': 2013,
#   'month': 1,
#   'day': 18,
#   'fulldate': '2013-01-18',
#   'fulltime': '10:17:03',
#   'fulldatewithtime': '2013-01-18T10:17:03',
#   'date': '2013-01-18'},
#  {'trans_id': 'T00682546',
#   'account_id': 'A00002330',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 19,
#   'fulldate': '2013-01-19',
#   'fulltime': '09:28:59',
#   'fulldatewithtime': '2013-01-19T09:28:59',
#   'date': '2013-01-19'},
#  {'trans_id': 'T00529772',
#   'account_id': 'A00001806',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 19,
#   'fulldate': '2013-01-19',
#   'fulltime': '15:16:58',
#   'fulldatewithtime': '2013-01-19T15:16:58',
#   'date': '2013-01-19'},
#  {'trans_id': 'T01121963',
#   'account_id': 'A00003834',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 19,
#   'fulldate': '2013-01-19',
#   'fulltime': '09:34:56',
#   'fulldatewithtime': '2013-01-19T09:34:56',
#   'date': '2013-01-19'},
#  {'trans_id': 'T00359511',
#   'account_id': 'A00001222',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 20,
#   'fulldate': '2013-01-20',
#   'fulltime': '11:07:02',
#   'fulldatewithtime': '2013-01-20T11:07:02',
#   'date': '2013-01-20'},
#  {'trans_id': 'T00063712',
#   'account_id': 'A00000212',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 20,
#   'fulldate': '2013-01-20',
#   'fulltime': '12:29:33',
#   'fulldatewithtime': '2013-01-20T12:29:33',
#   'date': '2013-01-20'},
#  {'trans_id': 'T00298978',
#   'account_id': 'A00001019',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 21,
#   'fulldate': '2013-01-21',
#   'fulltime': '15:60:16',
#   'fulldatewithtime': '2013-01-21T15:60:16',
#   'date': '2013-01-21'},
#  {'trans_id': 'T00136957',
#   'account_id': 'A00000459',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 21,
#   'fulldate': '2013-01-21',
#   'fulltime': '11:07:56',
#   'fulldatewithtime': '2013-01-21T11:07:56',
#   'date': '2013-01-21'},
#  {'trans_id': 'T00135814',
#   'account_id': 'A00000456',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 21,
#   'fulldate': '2013-01-21',
#   'fulltime': '08:28:34',
#   'fulldatewithtime': '2013-01-21T08:28:34',
#   'date': '2013-01-21'},
#  {'trans_id': 'T00226654',
#   'account_id': 'A00000772',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 21,
#   'fulldate': '2013-01-21',
#   'fulltime': '08:31:17',
#   'fulldatewithtime': '2013-01-21T08:31:17',
#   'date': '2013-01-21'},
#  {'trans_id': 'T03402664',
#   'account_id': 'A00011295',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 21,
#   'fulldate': '2013-01-21',
#   'fulltime': '13:38:31',
#   'fulldatewithtime': '2013-01-21T13:38:31',
#   'date': '2013-01-21'},
#  {'trans_id': 'T00695250',
#   'account_id': 'A00002378',
#   'type': 'Credit',
#   'amount': 7268.0,
#   'balance': 7968.0,
#   'year': 2013,
#   'month': 1,
#   'day': 22,
#   'fulldate': '2013-01-22',
#   'fulltime': '14:43:54',
#   'fulldatewithtime': '2013-01-22T14:43:54',
#   'date': '2013-01-22'},
#  {'trans_id': 'T00451890',
#   'account_id': 'A00001536',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 22,
#   'fulldate': '2013-01-22',
#   'fulltime': '11:17:36',
#   'fulldatewithtime': '2013-01-22T11:17:36',
#   'date': '2013-01-22'},
#  {'trans_id': 'T00785190',
#   'account_id': 'A00002676',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 22,
#   'fulldate': '2013-01-22',
#   'fulltime': '08:36:26',
#   'fulldatewithtime': '2013-01-22T08:36:26',
#   'date': '2013-01-22'},
#  {'trans_id': 'T00615548',
#   'account_id': 'A00002099',
#   'type': 'Credit',
#   'amount': 16125.0,
#   'balance': 17225.0,
#   'year': 2013,
#   'month': 1,
#   'day': 22,
#   'fulldate': '2013-01-22',
#   'fulltime': '15:37:35',
#   'fulldatewithtime': '2013-01-22T15:37:35',
#   'date': '2013-01-22'},
#  {'trans_id': 'T00871631',
#   'account_id': 'A00002970',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 22,
#   'fulldate': '2013-01-22',
#   'fulltime': '11:08:59',
#   'fulldatewithtime': '2013-01-22T11:08:59',
#   'date': '2013-01-22'},
#  {'trans_id': 'T00695266',
#   'account_id': 'A00002378',
#   'type': 'Credit',
#   'amount': 14440.0,
#   'balance': 22408.0,
#   'year': 2013,
#   'month': 1,
#   'day': 23,
#   'fulldate': '2013-01-23',
#   'fulltime': '13:56:58',
#   'fulldatewithtime': '2013-01-23T13:56:58',
#   'date': '2013-01-23'},
#  {'trans_id': 'T00347543',
#   'account_id': 'A00001179',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 23,
#   'fulldate': '2013-01-23',
#   'fulltime': '16:24:22',
#   'fulldatewithtime': '2013-01-23T16:24:22',
#   'date': '2013-01-23'},
#  {'trans_id': 'T00708081',
#   'account_id': 'A00002425',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 23,
#   'fulldate': '2013-01-23',
#   'fulltime': '12:17:12',
#   'fulldatewithtime': '2013-01-23T12:17:12',
#   'date': '2013-01-23'},
#  {'trans_id': 'T00083658',
#   'account_id': 'A00000280',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 23,
#   'fulldate': '2013-01-23',
#   'fulltime': '09:00:03',
#   'fulldatewithtime': '2013-01-23T09:00:03',
#   'date': '2013-01-23'},
#  {'trans_id': 'T00695262',
#   'account_id': 'A00002378',
#   'type': 'Credit',
#   'amount': 49752.0,
#   'balance': 72160.0,
#   'year': 2013,
#   'month': 1,
#   'day': 24,
#   'fulldate': '2013-01-24',
#   'fulltime': '08:37:03',
#   'fulldatewithtime': '2013-01-24T08:37:03',
#   'date': '2013-01-24'},
#  {'trans_id': 'T01183176',
#   'account_id': 'A00004055',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 24,
#   'fulldate': '2013-01-24',
#   'fulltime': '15:41:22',
#   'fulldatewithtime': '2013-01-24T15:41:22',
#   'date': '2013-01-24'},
#  {'trans_id': 'T00615547',
#   'account_id': 'A00002099',
#   'type': 'Credit',
#   'amount': 36518.0,
#   'balance': 53743.0,
#   'year': 2013,
#   'month': 1,
#   'day': 24,
#   'fulldate': '2013-01-24',
#   'fulltime': '12:49:54',
#   'fulldatewithtime': '2013-01-24T12:49:54',
#   'date': '2013-01-24'},
#  {'trans_id': 'T01084396',
#   'account_id': 'A00003704',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 24,
#   'fulldate': '2013-01-24',
#   'fulltime': '11:22:14',
#   'fulldatewithtime': '2013-01-24T11:22:14',
#   'date': '2013-01-24'},
#  {'trans_id': 'T02809952',
#   'account_id': 'A00009307',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 24,
#   'fulldate': '2013-01-24',
#   'fulltime': '08:23:55',
#   'fulldatewithtime': '2013-01-24T08:23:55',
#   'date': '2013-01-24'},
#  {'trans_id': 'T01486053',
#   'account_id': 'A00005065',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 24,
#   'fulldate': '2013-01-24',
#   'fulltime': '08:08:13',
#   'fulldatewithtime': '2013-01-24T08:08:13',
#   'date': '2013-01-24'},
#  {'trans_id': 'T01736607',
#   'account_id': 'A00005891',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 25,
#   'fulldate': '2013-01-25',
#   'fulltime': '14:46:59',
#   'fulldatewithtime': '2013-01-25T14:46:59',
#   'date': '2013-01-25'},
#  {'trans_id': 'T00142150',
#   'account_id': 'A00000477',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 25,
#   'fulldate': '2013-01-25',
#   'fulltime': '10:52:42',
#   'fulldatewithtime': '2013-01-25T10:52:42',
#   'date': '2013-01-25'},
#  {'trans_id': 'T00292053',
#   'account_id': 'A00001000',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 25,
#   'fulldate': '2013-01-25',
#   'fulltime': '15:30:35',
#   'fulldatewithtime': '2013-01-25T15:30:35',
#   'date': '2013-01-25'},
#  {'trans_id': 'T00695265',
#   'account_id': 'A00002378',
#   'type': 'Credit',
#   'amount': 21899.0,
#   'balance': 94059.0,
#   'year': 2013,
#   'month': 1,
#   'day': 26,
#   'fulldate': '2013-01-26',
#   'fulltime': '09:50:04',
#   'fulldatewithtime': '2013-01-26T09:50:04',
#   'date': '2013-01-26'},
#  {'trans_id': 'T00144551',
#   'account_id': 'A00000485',
#   'type': 'Credit',
#   'amount': 12336.0,
#   'balance': 25792.0,
#   'year': 2013,
#   'month': 1,
#   'day': 26,
#   'fulldate': '2013-01-26',
#   'fulltime': '16:33:48',
#   'fulldatewithtime': '2013-01-26T16:33:48',
#   'date': '2013-01-26'},
#  {'trans_id': 'T00511264',
#   'account_id': 'A00001750',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 26,
#   'fulldate': '2013-01-26',
#   'fulltime': '08:37:27',
#   'fulldatewithtime': '2013-01-26T08:37:27',
#   'date': '2013-01-26'},
#  {'trans_id': 'T00594014',
#   'account_id': 'A00002023',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 26,
#   'fulldate': '2013-01-26',
#   'fulltime': '16:08:35',
#   'fulldatewithtime': '2013-01-26T16:08:35',
#   'date': '2013-01-26'},
#  {'trans_id': 'T00484214',
#   'account_id': 'A00001649',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 1,
#   'day': 26,
#   'fulldate': '2013-01-26',
#   'fulltime': '09:24:38',
#   'fulldatewithtime': '2013-01-26T09:24:38',
#   'date': '2013-01-26'},
#  {'trans_id': 'T01910780',
#   'account_id': 'A00006473',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 26,
#   'fulldate': '2013-01-26',
#   'fulltime': '12:24:02',
#   'fulldatewithtime': '2013-01-26T12:24:02',
#   'date': '2013-01-26'},
#  {'trans_id': 'T01910790',
#   'account_id': 'A00006473',
#   'type': 'Credit',
#   'amount': 19961.0,
#   'balance': 21061.0,
#   'year': 2013,
#   'month': 1,
#   'day': 26,
#   'fulldate': '2013-01-26',
#   'fulltime': '16:47:38',
#   'fulldatewithtime': '2013-01-26T16:47:38',
#   'date': '2013-01-26'},
#  {'trans_id': 'T00048640',
#   'account_id': 'A00000163',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 1,
#   'day': 27,
#   'fulldate': '2013-01-27',
#   'fulltime': '13:02:13',
#   'fulldatewithtime': '2013-01-27T13:02:13',
#   'date': '2013-01-27'},
#  {'trans_id': 'T00783290',
#   'account_id': 'A00002670',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 1,
#   'day': 27,
#   'fulldate': '2013-01-27',
#   'fulltime': '10:46:47',
#   'fulldatewithtime': '2013-01-27T10:46:47',
#   'date': '2013-01-27'},
#  {'trans_id': 'T00752010',
#   'account_id': 'A00002566',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 27,
#   'fulldate': '2013-01-27',
#   'fulltime': '09:45:18',
#   'fulldatewithtime': '2013-01-27T09:45:18',
#   'date': '2013-01-27'},
#  {'trans_id': 'T00330659',
#   'account_id': 'A00001127',
#   'type': 'Credit',
#   'amount': 600.0,
#   'balance': 600.0,
#   'year': 2013,
#   'month': 1,
#   'day': 27,
#   'fulldate': '2013-01-27',
#   'fulltime': '13:50:39',
#   'fulldatewithtime': '2013-01-27T13:50:39',
#   'date': '2013-01-27'},
#  {'trans_id': 'T00002176',
#   'account_id': 'A00000009',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 27,
#   'fulldate': '2013-01-27',
#   'fulltime': '11:20:21',
#   'fulldatewithtime': '2013-01-27T11:20:21',
#   'date': '2013-01-27'},
#  {'trans_id': 'T00336631',
#   'account_id': 'A00001144',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 28,
#   'fulldate': '2013-01-28',
#   'fulltime': '12:37:48',
#   'fulldatewithtime': '2013-01-28T12:37:48',
#   'date': '2013-01-28'},
#  {'trans_id': 'T00131922',
#   'account_id': 'A00000443',
#   'type': 'Credit',
#   'amount': 500.0,
#   'balance': 500.0,
#   'year': 2013,
#   'month': 1,
#   'day': 28,
#   'fulldate': '2013-01-28',
#   'fulltime': '12:20:32',
#   'fulldatewithtime': '2013-01-28T12:20:32',
#   'date': '2013-01-28'},
#  {'trans_id': 'T01256504',
#   'account_id': 'A00004296',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 28,
#   'fulldate': '2013-01-28',
#   'fulltime': '15:44:33',
#   'fulldatewithtime': '2013-01-28T15:44:33',
#   'date': '2013-01-28'},
#  {'trans_id': 'T00851325',
#   'account_id': 'A00002902',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 1,
#   'day': 28,
#   'fulldate': '2013-01-28',
#   'fulltime': '14:23:21',
#   'fulldatewithtime': '2013-01-28T14:23:21',
#   'date': '2013-01-28'},
#  {'trans_id': 'T00393512',
#   'account_id': 'A00001338',
#   'type': 'Credit',
#   'amount': 38000.0,
#   'balance': 38400.0,
#   'year': 2013,
#   'month': 1,
#   'day': 29,
#   'fulldate': '2013-01-29',
#   'fulltime': '14:22:51',
#   'fulldatewithtime': '2013-01-29T14:22:51',
#   'date': '2013-01-29'},
#  {'trans_id': 'T00612405',
#   'account_id': 'A00002087',
#   'type': 'Credit',
#   'amount': 16983.0,
#   'balance': 17583.0,
#   'year': 2013,
#   'month': 1,
#   'day': 29,
#   'fulldate': '2013-01-29',
#   'fulltime': '10:49:51',
#   'fulldatewithtime': '2013-01-29T10:49:51',
#   'date': '2013-01-29'},
#  {'trans_id': 'T01081327',
#   'account_id': 'A00003693',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 29,
#   'fulldate': '2013-01-29',
#   'fulltime': '11:50:53',
#   'fulldatewithtime': '2013-01-29T11:50:53',
#   'date': '2013-01-29'},
#  {'trans_id': 'T00608135',
#   'account_id': 'A00002070',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 29,
#   'fulldate': '2013-01-29',
#   'fulltime': '08:50:19',
#   'fulldatewithtime': '2013-01-29T08:50:19',
#   'date': '2013-01-29'},
#  {'trans_id': 'T01190752',
#   'account_id': 'A00004078',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 1,
#   'day': 30,
#   'fulldate': '2013-01-30',
#   'fulltime': '13:21:36',
#   'fulldatewithtime': '2013-01-30T13:21:36',
#   'date': '2013-01-30'},
#  {'trans_id': 'T00541681',
#   'account_id': 'A00001843',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 1,
#   'day': 30,
#   'fulldate': '2013-01-30',
#   'fulltime': '10:33:19',
#   'fulldatewithtime': '2013-01-30T10:33:19',
#   'date': '2013-01-30'},
#  {'trans_id': 'T00796773',
#   'account_id': 'A00002714',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 1,
#   'day': 30,
#   'fulldate': '2013-01-30',
#   'fulltime': '08:03:28',
#   'fulldatewithtime': '2013-01-30T08:03:28',
#   'date': '2013-01-30'},
#  {'trans_id': 'T00695560',
#   'account_id': 'A00002378',
#   'type': 'Debit',
#   'amount': 34700.0,
#   'balance': 59453.7,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '10:26:13',
#   'fulldatewithtime': '2013-01-31T10:26:13',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03591421',
#   'account_id': 'A00001844',
#   'type': 'Credit',
#   'amount': 12.6,
#   'balance': 3754.6,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '10:00:55',
#   'fulldatewithtime': '2013-01-31T10:00:55',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03617490',
#   'account_id': 'A00002632',
#   'type': 'Credit',
#   'amount': 47.5,
#   'balance': 15411.5,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '11:21:06',
#   'fulldatewithtime': '2013-01-31T11:21:06',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03579543',
#   'account_id': 'A00001493',
#   'type': 'Credit',
#   'amount': 13.3,
#   'balance': 5222.3,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '08:43:41',
#   'fulldatewithtime': '2013-01-31T08:43:41',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03558798',
#   'account_id': 'A00000866',
#   'type': 'Credit',
#   'amount': 37.1,
#   'balance': 13181.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '09:37:14',
#   'fulldatewithtime': '2013-01-31T09:37:14',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03453599',
#   'account_id': 'A00006473',
#   'type': 'Credit',
#   'amount': 17.0,
#   'balance': 21078.0,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '15:36:15',
#   'fulldatewithtime': '2013-01-31T15:36:15',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03513134',
#   'account_id': 'A00009635',
#   'type': 'Credit',
#   'amount': 11.1,
#   'balance': 4892.9,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '14:03:25',
#   'fulldatewithtime': '2013-01-31T14:03:25',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03574567',
#   'account_id': 'A00001338',
#   'type': 'Credit',
#   'amount': 15.5,
#   'balance': 38415.5,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '16:32:01',
#   'fulldatewithtime': '2013-01-31T16:32:01',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03654666',
#   'account_id': 'A00003760',
#   'type': 'Credit',
#   'amount': 22.2,
#   'balance': 11814.2,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '13:35:59',
#   'fulldatewithtime': '2013-01-31T13:35:59',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03656579',
#   'account_id': 'A00003818',
#   'type': 'Credit',
#   'amount': 55.8,
#   'balance': 18021.8,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '08:42:48',
#   'fulldatewithtime': '2013-01-31T08:42:48',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03456844',
#   'account_id': 'A00009635',
#   'type': 'Credit',
#   'amount': 11.8,
#   'balance': 4881.8,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '14:04:15',
#   'fulldatewithtime': '2013-01-31T14:04:15',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03553661',
#   'account_id': 'A00000704',
#   'type': 'Credit',
#   'amount': 50.1,
#   'balance': 18527.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '13:41:56',
#   'fulldatewithtime': '2013-01-31T13:41:56',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03552056',
#   'account_id': 'A00000652',
#   'type': 'Credit',
#   'amount': 45.0,
#   'balance': 14596.0,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '12:09:11',
#   'fulldatewithtime': '2013-01-31T12:09:11',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03583848',
#   'account_id': 'A00001628',
#   'type': 'Credit',
#   'amount': 13.4,
#   'balance': 4989.4,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '11:25:03',
#   'fulldatewithtime': '2013-01-31T11:25:03',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03584201',
#   'account_id': 'A00001637',
#   'type': 'Credit',
#   'amount': 15.9,
#   'balance': 6233.9,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '12:03:10',
#   'fulldatewithtime': '2013-01-31T12:03:10',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03586191',
#   'account_id': 'A00001695',
#   'type': 'Credit',
#   'amount': 38.8,
#   'balance': 12070.8,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '16:27:47',
#   'fulldatewithtime': '2013-01-31T16:27:47',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03587145',
#   'account_id': 'A00001726',
#   'type': 'Credit',
#   'amount': 38.2,
#   'balance': 15005.2,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '16:15:34',
#   'fulldatewithtime': '2013-01-31T16:15:34',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03549613',
#   'account_id': 'A00000576',
#   'type': 'Credit',
#   'amount': 20.1,
#   'balance': 7127.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '14:09:30',
#   'fulldatewithtime': '2013-01-31T14:09:30',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03546683',
#   'account_id': 'A00000485',
#   'type': 'Credit',
#   'amount': 38.9,
#   'balance': 25830.9,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '08:00:18',
#   'fulldatewithtime': '2013-01-31T08:00:18',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03599467',
#   'account_id': 'A00002087',
#   'type': 'Credit',
#   'amount': 7.1,
#   'balance': 17590.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '10:29:50',
#   'fulldatewithtime': '2013-01-31T10:29:50',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03600403',
#   'account_id': 'A00002122',
#   'type': 'Credit',
#   'amount': 107.1,
#   'balance': 46959.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '15:53:05',
#   'fulldatewithtime': '2013-01-31T15:53:05',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03466049',
#   'account_id': 'A00003510',
#   'type': 'Credit',
#   'amount': 48.0,
#   'balance': 23871.0,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '16:06:06',
#   'fulldatewithtime': '2013-01-31T16:06:06',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03444292',
#   'account_id': 'A00002099',
#   'type': 'Credit',
#   'amount': 62.4,
#   'balance': 53805.4,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '11:50:04',
#   'fulldatewithtime': '2013-01-31T11:50:04',
#   'date': '2013-01-31'},
#  {'trans_id': 'T00207642',
#   'account_id': 'A00000704',
#   'type': 'Credit',
#   'amount': 2900.0,
#   'balance': 21427.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '13:00:11',
#   'fulldatewithtime': '2013-01-31T13:00:11',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03602138',
#   'account_id': 'A00002177',
#   'type': 'Credit',
#   'amount': 21.5,
#   'balance': 5944.5,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '14:21:32',
#   'fulldatewithtime': '2013-01-31T14:21:32',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03595783',
#   'account_id': 'A00001972',
#   'type': 'Credit',
#   'amount': 19.1,
#   'balance': 5717.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '15:34:56',
#   'fulldatewithtime': '2013-01-31T15:34:56',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03594124',
#   'account_id': 'A00001926',
#   'type': 'Credit',
#   'amount': 14.0,
#   'balance': 5221.0,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '13:15:20',
#   'fulldatewithtime': '2013-01-31T13:15:20',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03648651',
#   'account_id': 'A00003592',
#   'type': 'Credit',
#   'amount': 19.5,
#   'balance': 6626.5,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '11:11:38',
#   'fulldatewithtime': '2013-01-31T11:11:38',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03645341',
#   'account_id': 'A00003487',
#   'type': 'Credit',
#   'amount': 42.7,
#   'balance': 16756.7,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '09:30:58',
#   'fulldatewithtime': '2013-01-31T09:30:58',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03556397',
#   'account_id': 'A00000793',
#   'type': 'Credit',
#   'amount': 15.2,
#   'balance': 4216.2,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '09:01:07',
#   'fulldatewithtime': '2013-01-31T09:01:07',
#   'date': '2013-01-31'},
#  {'trans_id': 'T02809959',
#   'account_id': 'A00009307',
#   'type': 'Credit',
#   'amount': 5282.0,
#   'balance': 6182.0,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '15:60:01',
#   'fulldatewithtime': '2013-01-31T15:60:01',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03608592',
#   'account_id': 'A00002378',
#   'type': 'Credit',
#   'amount': 94.7,
#   'balance': 94153.7,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '09:23:30',
#   'fulldatewithtime': '2013-01-31T09:23:30',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03607855',
#   'account_id': 'A00002357',
#   'type': 'Credit',
#   'amount': 19.4,
#   'balance': 7253.4,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
#   'fulltime': '09:42:56',
#   'fulldatewithtime': '2013-01-31T09:42:56',
#   'date': '2013-01-31'},
#  {'trans_id': 'T03609127',
#   'account_id': 'A00002393',
#   'type': 'Credit',
#   'amount': 28.2,
#   'balance': 11665.1,
#   'year': 2013,
#   'month': 1,
#   'day': 31,
#   'fulldate': '2013-01-31',
# ...
#   'fulldatewithtime': '2013-03-22T16:15:51',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00137125',
#   'account_id': 'A00000459',
#   'type': 'Credit',
#   'amount': 3100.0,
#   'balance': 17500.0,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '10:04:00',
#   'fulldatewithtime': '2013-03-22T10:04:00',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00136149',
#   'account_id': 'A00000456',
#   'type': 'Debit',
#   'amount': 29400.0,
#   'balance': 56512.9,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '13:22:18',
#   'fulldatewithtime': '2013-03-22T13:22:18',
#   'date': '2013-03-22'},
#  {'trans_id': 'T01602507',
#   'account_id': 'A00005442',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '14:56:10',
#   'fulldatewithtime': '2013-03-22T14:56:10',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00523621',
#   'account_id': 'A00001787',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '15:03:60',
#   'fulldatewithtime': '2013-03-22T15:03:60',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00227106',
#   'account_id': 'A00000772',
#   'type': 'Debit',
#   'amount': 12600.0,
#   'balance': 35350.0,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '11:20:14',
#   'fulldatewithtime': '2013-03-22T11:20:14',
#   'date': '2013-03-22'},
#  {'trans_id': 'T01450518',
#   'account_id': 'A00004937',
#   'type': 'Debit',
#   'amount': 16400.0,
#   'balance': 37574.7,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '14:09:41',
#   'fulldatewithtime': '2013-03-22T14:09:41',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00622996',
#   'account_id': 'A00002124',
#   'type': 'Credit',
#   'amount': 2100.0,
#   'balance': 24031.0,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '10:15:14',
#   'fulldatewithtime': '2013-03-22T10:15:14',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00410110',
#   'account_id': 'A00001397',
#   'type': 'Credit',
#   'amount': 700.0,
#   'balance': 700.0,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '13:15:42',
#   'fulldatewithtime': '2013-03-22T13:15:42',
#   'date': '2013-03-22'},
#  {'trans_id': 'T03403039',
#   'account_id': 'A00011295',
#   'type': 'Debit',
#   'amount': 10700.0,
#   'balance': 30852.6,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '09:54:38',
#   'fulldatewithtime': '2013-03-22T09:54:38',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00094940',
#   'account_id': 'A00000322',
#   'type': 'Credit',
#   'amount': 3600.0,
#   'balance': 21246.0,
#   'year': 2013,
#   'month': 3,
#   'day': 22,
#   'fulldate': '2013-03-22',
#   'fulltime': '10:27:54',
#   'fulldatewithtime': '2013-03-22T10:27:54',
#   'date': '2013-03-22'},
#  {'trans_id': 'T00452239',
#   'account_id': 'A00001536',
#   'type': 'Debit',
#   'amount': 11900.0,
#   'balance': 39749.0,
#   'year': 2013,
#   'month': 3,
#   'day': 23,
#   'fulldate': '2013-03-23',
#   'fulltime': '16:33:31',
#   'fulldatewithtime': '2013-03-23T16:33:31',
#   'date': '2013-03-23'},
#  {'trans_id': 'T00785633',
#   'account_id': 'A00002676',
#   'type': 'Debit',
#   'amount': 4500.0,
#   'balance': 29548.3,
#   'year': 2013,
#   'month': 3,
#   'day': 23,
#   'fulldate': '2013-03-23',
#   'fulltime': '10:01:04',
#   'fulldatewithtime': '2013-03-23T10:01:04',
#   'date': '2013-03-23'},
#  {'trans_id': 'T01273578',
#   'account_id': 'A00004355',
#   'type': 'Credit',
#   'amount': 12500.0,
#   'balance': 16200.0,
#   'year': 2013,
#   'month': 3,
#   'day': 23,
#   'fulldate': '2013-03-23',
#   'fulltime': '15:54:11',
#   'fulldatewithtime': '2013-03-23T15:54:11',
#   'date': '2013-03-23'},
#  {'trans_id': 'T02135189',
#   'account_id': 'A00007231',
#   'type': 'Credit',
#   'amount': 46824.0,
#   'balance': 62273.0,
#   'year': 2013,
#   'month': 3,
#   'day': 23,
#   'fulldate': '2013-03-23',
#   'fulltime': '16:10:09',
#   'fulldatewithtime': '2013-03-23T16:10:09',
#   'date': '2013-03-23'},
#  {'trans_id': 'T02135185',
#   'account_id': 'A00007231',
#   'type': 'Credit',
#   'amount': 14949.0,
#   'balance': 15449.0,
#   'year': 2013,
#   'month': 3,
#   'day': 23,
#   'fulldate': '2013-03-23',
#   'fulltime': '15:05:10',
#   'fulldatewithtime': '2013-03-23T15:05:10',
#   'date': '2013-03-23'},
#  {'trans_id': 'T00871810',
#   'account_id': 'A00002970',
#   'type': 'Debit',
#   'amount': 4300.0,
#   'balance': 24839.2,
#   'year': 2013,
#   'month': 3,
#   'day': 23,
#   'fulldate': '2013-03-23',
#   'fulltime': '09:58:54',
#   'fulldatewithtime': '2013-03-23T09:58:54',
#   'date': '2013-03-23'},
#  {'trans_id': 'T01935478',
#   'account_id': 'A00006555',
#   'type': 'Credit',
#   'amount': 39703.0,
#   'balance': 52804.0,
#   'year': 2013,
#   'month': 3,
#   'day': 23,
#   'fulldate': '2013-03-23',
#   'fulltime': '13:16:14',
#   'fulldatewithtime': '2013-03-23T13:16:14',
#   'date': '2013-03-23'},
#  {'trans_id': 'T01108017',
#   'account_id': 'A00003785',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '13:18:20',
#   'fulldatewithtime': '2013-03-24T13:18:20',
#   'date': '2013-03-24'},
#  {'trans_id': 'T01076496',
#   'account_id': 'A00003678',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '12:07:14',
#   'fulldatewithtime': '2013-03-24T12:07:14',
#   'date': '2013-03-24'},
#  {'trans_id': 'T00183005',
#   'account_id': 'A00000623',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '16:05:30',
#   'fulldatewithtime': '2013-03-24T16:05:30',
#   'date': '2013-03-24'},
#  {'trans_id': 'T01657162',
#   'account_id': 'A00005622',
#   'type': 'Credit',
#   'amount': 43050.0,
#   'balance': 86373.2,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '09:22:18',
#   'fulldatewithtime': '2013-03-24T09:22:18',
#   'date': '2013-03-24'},
#  {'trans_id': 'T02501876',
#   'account_id': 'A00008260',
#   'type': 'Credit',
#   'amount': 200.0,
#   'balance': 200.0,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '08:57:04',
#   'fulldatewithtime': '2013-03-24T08:57:04',
#   'date': '2013-03-24'},
#  {'trans_id': 'T00880801',
#   'account_id': 'A00003001',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '11:24:43',
#   'fulldatewithtime': '2013-03-24T11:24:43',
#   'date': '2013-03-24'},
#  {'trans_id': 'T01450016',
#   'account_id': 'A00004937',
#   'type': 'Credit',
#   'amount': 18790.0,
#   'balance': 56364.7,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '09:04:37',
#   'fulldatewithtime': '2013-03-24T09:04:37',
#   'date': '2013-03-24'},
#  {'trans_id': 'T00192918',
#   'account_id': 'A00000655',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '09:57:55',
#   'fulldatewithtime': '2013-03-24T09:57:55',
#   'date': '2013-03-24'},
#  {'trans_id': 'T00084102',
#   'account_id': 'A00000280',
#   'type': 'Debit',
#   'amount': 5100.0,
#   'balance': 25505.3,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '09:04:28',
#   'fulldatewithtime': '2013-03-24T09:04:28',
#   'date': '2013-03-24'},
#  {'trans_id': 'T00708373',
#   'account_id': 'A00002425',
#   'type': 'Debit',
#   'amount': 800.0,
#   'balance': 25928.5,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '13:14:57',
#   'fulldatewithtime': '2013-03-24T13:14:57',
#   'date': '2013-03-24'},
#  {'trans_id': 'T00492187',
#   'account_id': 'A00001678',
#   'type': 'Debit',
#   'amount': 200.0,
#   'balance': 23116.0,
#   'year': 2013,
#   'month': 3,
#   'day': 24,
#   'fulldate': '2013-03-24',
#   'fulltime': '09:08:23',
#   'fulldatewithtime': '2013-03-24T09:08:23',
#   'date': '2013-03-24'},
#  {'trans_id': 'T00270133',
#   'account_id': 'A00000925',
#   'type': 'Credit',
#   'amount': 4200.0,
#   'balance': 23200.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '13:06:21',
#   'fulldatewithtime': '2013-03-25T13:06:21',
#   'date': '2013-03-25'},
#  {'trans_id': 'T01195278',
#   'account_id': 'A00004093',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '12:10:38',
#   'fulldatewithtime': '2013-03-25T12:10:38',
#   'date': '2013-03-25'},
#  {'trans_id': 'T01183400',
#   'account_id': 'A00004055',
#   'type': 'Debit',
#   'amount': 7700.0,
#   'balance': 36183.1,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '10:31:36',
#   'fulldatewithtime': '2013-03-25T10:31:36',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00391494',
#   'account_id': 'A00001332',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '14:25:24',
#   'fulldatewithtime': '2013-03-25T14:25:24',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00740439',
#   'account_id': 'A00002528',
#   'type': 'Credit',
#   'amount': 1000.0,
#   'balance': 1000.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '09:46:33',
#   'fulldatewithtime': '2013-03-25T09:46:33',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00294327',
#   'account_id': 'A00001005',
#   'type': 'Debit',
#   'amount': 5400.0,
#   'balance': 29383.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '14:08:58',
#   'fulldatewithtime': '2013-03-25T14:08:58',
#   'date': '2013-03-25'},
#  {'trans_id': 'T01100772',
#   'account_id': 'A00003760',
#   'type': 'Credit',
#   'amount': 24226.0,
#   'balance': 65734.7,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '15:13:13',
#   'fulldatewithtime': '2013-03-25T15:13:13',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00726530',
#   'account_id': 'A00002486',
#   'type': 'Credit',
#   'amount': 38820.0,
#   'balance': 39020.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '10:24:13',
#   'fulldatewithtime': '2013-03-25T10:24:13',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00810150',
#   'account_id': 'A00002762',
#   'type': 'Credit',
#   'amount': 30360.0,
#   'balance': 30860.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '14:02:15',
#   'fulldatewithtime': '2013-03-25T14:02:15',
#   'date': '2013-03-25'},
#  {'trans_id': 'T01602508',
#   'account_id': 'A00005442',
#   'type': 'Credit',
#   'amount': 7651.0,
#   'balance': 7951.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '13:42:11',
#   'fulldatewithtime': '2013-03-25T13:42:11',
#   'date': '2013-03-25'},
#  {'trans_id': 'T02810463',
#   'account_id': 'A00009307',
#   'type': 'Debit',
#   'amount': 1300.0,
#   'balance': 28557.6,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '16:57:53',
#   'fulldatewithtime': '2013-03-25T16:57:53',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00590834',
#   'account_id': 'A00002011',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '15:46:29',
#   'fulldatewithtime': '2013-03-25T15:46:29',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00504193',
#   'account_id': 'A00001721',
#   'type': 'Credit',
#   'amount': 1100.0,
#   'balance': 1100.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '12:26:32',
#   'fulldatewithtime': '2013-03-25T12:26:32',
#   'date': '2013-03-25'},
#  {'trans_id': 'T01486386',
#   'account_id': 'A00005065',
#   'type': 'Debit',
#   'amount': 5000.0,
#   'balance': 24371.2,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '10:32:26',
#   'fulldatewithtime': '2013-03-25T10:32:26',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00205250',
#   'account_id': 'A00000697',
#   'type': 'Credit',
#   'amount': 2000.0,
#   'balance': 24267.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '14:26:60',
#   'fulldatewithtime': '2013-03-25T14:26:60',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00956572',
#   'account_id': 'A00003260',
#   'type': 'Credit',
#   'amount': 400.0,
#   'balance': 400.0,
#   'year': 2013,
#   'month': 3,
#   'day': 25,
#   'fulldate': '2013-03-25',
#   'fulltime': '08:57:50',
#   'fulldatewithtime': '2013-03-25T08:57:50',
#   'date': '2013-03-25'},
#  {'trans_id': 'T00963184',
#   'account_id': 'A00003283',
#   'type': 'Credit',
#   'amount': 300.0,
#   'balance': 300.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '14:05:08',
#   'fulldatewithtime': '2013-03-26T14:05:08',
#   'date': '2013-03-26'},
#  {'trans_id': 'T01779034',
#   'account_id': 'A00006034',
#   'type': 'Credit',
#   'amount': 23851.0,
#   'balance': 24051.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '10:42:08',
#   'fulldatewithtime': '2013-03-26T10:42:08',
#   'date': '2013-03-26'},
#  {'trans_id': 'T01736951',
#   'account_id': 'A00005891',
#   'type': 'Debit',
#   'amount': 20200.0,
#   'balance': 41409.6,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '13:27:24',
#   'fulldatewithtime': '2013-03-26T13:27:24',
#   'date': '2013-03-26'},
#  {'trans_id': 'T01106913',
#   'account_id': 'A00003781',
#   'type': 'Credit',
#   'amount': 800.0,
#   'balance': 800.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '13:21:53',
#   'fulldatewithtime': '2013-03-26T13:21:53',
#   'date': '2013-03-26'},
#  {'trans_id': 'T00144560',
#   'account_id': 'A00000485',
#   'type': 'Credit',
#   'amount': 49112.0,
#   'balance': 93768.9,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '09:34:50',
#   'fulldatewithtime': '2013-03-26T09:34:50',
#   'date': '2013-03-26'},
#  {'trans_id': 'T00142593',
#   'account_id': 'A00000477',
#   'type': 'Debit',
#   'amount': 4400.0,
#   'balance': 30297.6,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '14:51:16',
#   'fulldatewithtime': '2013-03-26T14:51:16',
#   'date': '2013-03-26'},
#  {'trans_id': 'T00144918',
#   'account_id': 'A00000485',
#   'type': 'Debit',
#   'amount': 5166.0,
#   'balance': 88602.9,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '09:52:25',
#   'fulldatewithtime': '2013-03-26T09:52:25',
#   'date': '2013-03-26'},
#  {'trans_id': 'T01977575',
#   'account_id': 'A00006701',
#   'type': 'Credit',
#   'amount': 29082.0,
#   'balance': 29282.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '10:36:58',
#   'fulldatewithtime': '2013-03-26T10:36:58',
#   'date': '2013-03-26'},
#  {'trans_id': 'T01602509',
#   'account_id': 'A00005442',
#   'type': 'Credit',
#   'amount': 34681.0,
#   'balance': 42632.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '16:56:19',
#   'fulldatewithtime': '2013-03-26T16:56:19',
#   'date': '2013-03-26'},
#  {'trans_id': 'T02127306',
#   'account_id': 'A00007203',
#   'type': 'Credit',
#   'amount': 900.0,
#   'balance': 900.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '13:36:05',
#   'fulldatewithtime': '2013-03-26T13:36:05',
#   'date': '2013-03-26'},
#  {'trans_id': 'T00308090',
#   'account_id': 'A00001050',
#   'type': 'Debit',
#   'amount': 800.0,
#   'balance': 25517.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '10:21:32',
#   'fulldatewithtime': '2013-03-26T10:21:32',
#   'date': '2013-03-26'},
#  {'trans_id': 'T00401329',
#   'account_id': 'A00001366',
#   'type': 'Credit',
#   'amount': 5200.0,
#   'balance': 13726.0,
#   'year': 2013,
#   'month': 3,
#   'day': 26,
#   'fulldate': '2013-03-26',
#   'fulltime': '16:28:13',
#   'fulldatewithtime': '2013-03-26T16:28:13',
#   'date': '2013-03-26'},
#  ...]

# %%
#creating new database in mongodb
db = client["GDDA707"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-btjms2e-shard-00-00.s7xdaor.mongodb.net:27017', 'ac-btjms2e-shard-00-02.s7xdaor.mongodb.net:27017', 'ac-btjms2e-shard-00-01.s7xdaor.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='MongoDBCluster', authsource='admin', replicaset='atlas-sbhm9z-shard-0', tls=True), 'GDDA707')

# %%
#insert data into mongodb
db.GDDA707A2.insert_many(data_list)
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1010, in Connection.send_message(self, message, max_doc_size)
#    1009 try:
# -> 1010     self.conn.sendall(message)
#    1011 except BaseException as error:
#
# File ~\anaconda3\Lib\site-packages\pymongo\pyopenssl_context.py:168, in _sslConn.sendall(self, buf, flags)
#     167 try:
# --> 168     sent = self._call(super().send, view[total_sent:], flags)
#     169 # XXX: It's not clear if this can actually happen. PyOpenSSL
#     170 # doesn't appear to have any interrupt handling, nor any interrupt
#     171 # errors for OpenSSL connections.
#
# File ~\anaconda3\Lib\site-packages\pymongo\pyopenssl_context.py:120, in _sslConn._call(self, call, *args, **kwargs)
#     119 try:
# --> 120     return call(*args, **kwargs)
#     121 except BLOCKING_IO_ERRORS as exc:
#     122     # Check for closed socket.
#
# File ~\anaconda3\Lib\site-packages\OpenSSL\SSL.py:2007, in Connection.send(self, buf, flags)
#    2006 result = _lib.SSL_write(self._ssl, data, len(data))
# -> 2007 self._raise_ssl_error(self._ssl, result)
#    2009 return result
#
# File ~\anaconda3\Lib\site-packages\OpenSSL\SSL.py:1807, in Connection._raise_ssl_error(self, ssl, result)
#    1806     if errno != 0:
# -> 1807         raise SysCallError(errno, errorcode.get(errno))
#    1808 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (10054, 'WSAECONNRESET')
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# Cell In[28], line 2
#       1 #insert data into mongodb
# ----> 2 db.GDDA707A2.insert_many(data_list)
#
# File ~\anaconda3\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# --> 755 blk.execute(write_concern, session=session)
#     756 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:576, in _Bulk.execute(self, write_concern, session)
#     574         return None
#     575 else:
# --> 576     return self.execute_command(generator, write_concern, session)
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:443, in _Bulk.execute_command(self, generator, write_concern, session)
#     432     self._execute_command(
#     433         generator,
#     434         write_concern,
#    (...)
#     439         full_result,
#     440     )
#     442 client = self.collection.database.client
# --> 443 client._retryable_write(self.is_retryable, retryable_bulk, session, bulk=self)
#     445 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     446     _raise_bulk_write_error(full_result)
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File ~\anaconda3\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:432, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     429 def retryable_bulk(
#     430     session: Optional[ClientSession], conn: Connection, retryable: bool
#     431 ) -> None:
# --> 432     self._execute_command(
#     433         generator,
#     434         write_concern,
#     435         session,
#     436         conn,
#     437         op_id,
#     438         retryable,
#     439         full_result,
#     440     )
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:378, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     376 # Run as many ops as possible in one command.
#     377 if write_concern.acknowledged:
# --> 378     result, to_send = bwc.execute(cmd, ops, client)
#     380     # Retryable writeConcernErrors halt the execution of this run.
#     381     wce = result.get("writeConcernError", {})
#
# File ~\anaconda3\Lib\site-packages\pymongo\message.py:964, in _BulkWriteContext.execute(self, cmd, docs, client)
#     960 def execute(
#     961     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]], client: MongoClient
#     962 ) -> tuple[Mapping[str, Any], list[Mapping[str, Any]]]:
#     963     request_id, msg, to_send = self.__batch_command(cmd, docs)
# --> 964     result = self.write_command(cmd, request_id, msg, to_send)
#     965     client._process_response(result, self.session)
#     966     return result, to_send
#
# File ~\anaconda3\Lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~\anaconda3\Lib\site-packages\pymongo\message.py:1058, in _BulkWriteContext.write_command(self, cmd, request_id, msg, docs)
#    1056     start = datetime.datetime.now()
#    1057 try:
# -> 1058     reply = self.conn.write_command(request_id, msg, self.codec)
#    1059     if self.publish:
#    1060         duration = (datetime.datetime.now() - start) + duration
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1055, in Connection.write_command(self, request_id, msg, codec_options)
#    1044 def write_command(
#    1045     self, request_id: int, msg: bytes, codec_options: CodecOptions
#    1046 ) -> dict[str, Any]:
#    1047     """Send "insert" etc. command, returning response as a dict.
#    1048
#    1049     Can raise ConnectionFailure or OperationFailure.
#    (...)
#    1053       - `msg`: bytes, the command message.
#    1054     """
# -> 1055     self.send_message(msg, 0)
#    1056     reply = self.receive_message(request_id)
#    1057     result = reply.command_response(codec_options)
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1012, in Connection.send_message(self, message, max_doc_size)
#    1010     self.conn.sendall(message)
#    1011 except BaseException as error:
# -> 1012     self._raise_connection_failure(error)
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1171, in Connection._raise_connection_failure(self, error)
#    1169 if isinstance(error, (IOError, OSError, SSLError)):
#    1170     details = _get_timeout_details(self.opts)
# -> 1171     _raise_connection_failure(self.address, error, timeout_details=details)
#    1172 else:
#    1173     raise
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:411, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     409     raise NetworkTimeout(msg) from error
#     410 else:
# --> 411     raise AutoReconnect(msg) from error
#
# AutoReconnect: ac-btjms2e-shard-00-02.s7xdaor.mongodb.net:27017: (10054, 'WSAECONNRESET') (configured timeouts: connectTimeoutMS: 20000.0ms)

# %%
#close the mongodb connection
client.close()
